# %% [markdown]
# <a href="https://colab.research.google.com/github/IssOT/PRAKTIKUM-DAN-PENUGASAN-PEMROGRAMAN-BERBASIS-OBJEK/blob/Jobshet-12/JOBSHEET_12_Integrasi_OOP_dalam_Mini_Project_Sistem_Informasi_Geografis_(SIG)_IVNA_SIGIT_SANTOSO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # JOBSHEET 12: Integrasi OOP dalam Mini Project Sistem Informasi Geografis (SIG)
#
#
#
# ---
# **Mata Kuliah:** Pemrograman Berorientasi Objek (432-242-206)
# **Dosen:** Ir. Prayitno, S.ST., M.T., Ph.D.
# ```
# Nama: Ivan Sigit Santoso
# NIM: 4.33.25.1.11
# KELAS: TI-1B
# ```

# %% [markdown]
# ## Install Library

# %%
# !pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2026.5.20)

# %% [markdown]
# ---
# ### Langkah 1: Praktikum 1 — Persiapan Data (Membuat File CSV)

# %%
# Praktikum 1: Membuat file CSV lokasi_semarang.csv
csv_content = """Nama,Latitude,Longitude,Tipe,Deskripsi
Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
Simpang Lima,-6.9929,110.4200,Landmark,"Alun-alun pusat kota Semarang, tempat berkumpul populer."
Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.
Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
Brown Canyon,-7.0375,110.4875,Wisata Alam,"Tebing bekas penambangan galian C yang unik menyerupai Grand Canyon."
Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris dan otentik di Semarang.
Kota Lama,-6.9690,110.4250,Wisata Sejarah,"Kawasan cagar budaya dengan bangunan-bangunan kuno bergaya Eropa."
Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi di bagian utara kota.
Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,"Agrowisata kebun kopi dengan pemandangan dan restoran."
Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris sejak zaman kolonial.
"""

with open('lokasi_semarang.csv', 'w', encoding='utf-8') as f:
    f.write(csv_content)

print("File lokasi_semarang.csv berhasil dibuat.")
print("Isi file:")
with open('lokasi_semarang.csv', 'r', encoding='utf-8') as f:
    print(f.read())
# Out:
# File lokasi_semarang.csv berhasil dibuat.
# Isi file:
# Nama,Latitude,Longitude,Tipe,Deskripsi
# Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
# Simpang Lima,-6.9929,110.4200,Landmark,"Alun-alun pusat kota Semarang, tempat berkumpul populer."
# Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.
# Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
# Brown Canyon,-7.0375,110.4875,Wisata Alam,"Tebing bekas penambangan galian C yang unik menyerupai Grand Canyon."
# Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris dan otentik di Semarang.
# Kota Lama,-6.9690,110.4250,Wisata Sejarah,"Kawasan cagar budaya dengan bangunan-bangunan kuno bergaya Eropa."
# Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi di bagian utara kota.
# Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,"Agrowisata kebun kopi dengan pemandangan dan restoran."
# Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris sejak zaman kolonial.

# %% [markdown]
# ---
# ### Langkah 2: Praktikum 2 — Membaca Data CSV dengan Pandas

# %%
# Praktikum 2: Membaca Data CSV dengan Pandas
import pandas as pd

NAMA_FILE_CSV = "lokasi_semarang.csv"

def baca_data_lokasi(nama_file: str):
    """
    Membaca data lokasi dari file CSV menggunakan Pandas.

    Args:
        nama_file (str): Path atau nama file CSV yang akan dibaca.

    Returns:
        pd.DataFrame | None: DataFrame Pandas berisi data jika berhasil,
                             None jika file tidak ditemukan atau error lain.
    """
    print(f"Mencoba membaca file CSV: {nama_file}")
    try:
        dataframe = pd.read_csv(nama_file)
        print(" -> File CSV berhasil dibaca.")
        return dataframe
    except FileNotFoundError:
        print(f" -> ERROR: File '{nama_file}' tidak ditemukan!")
        return None
    except pd.errors.EmptyDataError:
        print(f" -> ERROR: File '{nama_file}' kosong.")
        return None
    except Exception as e:
        print(f" -> ERROR saat membaca file CSV: {type(e).__name__} - {e}")
        return None

# --- Kode Utama ---
print("--- Memulai Praktikum 2: Membaca CSV ---")
df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)

if df_lokasi is not None:
    print("\n--- Inspeksi Awal DataFrame ---")

    print("\n1. Lima Baris Pertama (head()):")
    print(df_lokasi.head())

    print("\n2. Informasi DataFrame (info()):")
    df_lokasi.info()

    jumlah_baris, jumlah_kolom = df_lokasi.shape
    print(f"\n3. Dimensi Data:")
    print(f"   Jumlah Lokasi (Baris) : {jumlah_baris}")
    print(f"   Jumlah Atribut (Kolom): {jumlah_kolom}")

    print(f"\n4. Nama Kolom:")
    print(list(df_lokasi.columns))
else:
    print("\nTidak dapat melanjutkan inspeksi karena gagal membaca file CSV.")

print("\n--- Praktikum 2 Selesai ---")
# Out:
# --- Memulai Praktikum 2: Membaca CSV ---
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# --- Inspeksi Awal DataFrame ---
#
# 1. Lima Baris Pertama (head()):
#                        Nama  Latitude  Longitude            Tipe  \
# 0               Lawang Sewu   -6.9840   110.4105  Wisata Sejarah
# 1              Simpang Lima   -6.9929   110.4200        Landmark
# 2  Masjid Agung Jawa Tengah   -6.9892   110.4452   Tempat Ibadah
# 3     Klenteng Sam Poo Kong   -6.9980   110.4030   Tempat Ibadah
# 4              Brown Canyon   -7.0375   110.4875     Wisata Alam
#
#                                            Deskripsi
# 0  Bangunan bersejarah peninggalan Belanda dengan...
# 1  Alun-alun pusat kota Semarang, tempat berkumpu...
# 2  Masjid besar dengan arsitektur megah dan menar...
# 3  Klenteng bersejarah peninggalan Laksamana Chen...
# 4  Tebing bekas penambangan galian C yang unik me...
#
# 2. Informasi DataFrame (info()):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nama       10 non-null     object
#  1   Latitude   10 non-null     float64
#  2   Longitude  10 non-null     float64
#  3   Tipe       10 non-null     object
#  4   Deskripsi  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes
#
# 3. Dimensi Data:
#    Jumlah Lokasi (Baris) : 10
#    Jumlah Atribut (Kolom): 5
#
# 4. Nama Kolom:
# ['Nama', 'Latitude', 'Longitude', 'Tipe', 'Deskripsi']
#
# --- Praktikum 2 Selesai ---

# %% [markdown]
# ---
# ### Langkah 3: Praktikum 3 — Mendesain dan Membuat Kelas OOP

# %%
# Praktikum 3: Mendesain dan Membuat Kelas OOP
from abc import ABC, abstractmethod

class Lokasi(ABC):
    def __init__(self, nama: str, latitude: float, longitude: float):
        self.nama = str(nama) if nama else "Tanpa Nama"
        try:
            self.latitude = float(latitude)
            self.longitude = float(longitude)
        except (ValueError, TypeError, SystemError):
            self.latitude = 0.0
            self.longitude = 0.0

    def get_koordinat(self) -> tuple:
        return (self.latitude, self.longitude)

    @abstractmethod
    def get_info_popup(self) -> str:
        pass

    def __repr__(self) -> str:
        return f"{type(self).__name__}(nama='{self.nama}', lat={self.latitude:.4f}, lon={self.longitude:.4f})"

    def __str__(self) -> str:
        return f"{self.nama} [{type(self).__name__}]"


class TempatWisata(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, jenis: str, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.jenis_wisata = str(jenis) if jenis else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi."

    def get_info_popup(self) -> str:
        return (f"<h4><b>{self.nama}</b></h4>"
                f"<i>{self.jenis_wisata}</i><br><br>"
                f"{self.deskripsi}<br><br>"
                f"Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})")


class Kuliner(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, menu_andalan: str):
        super().__init__(nama, latitude, longitude)
        self.menu_andalan = str(menu_andalan) if menu_andalan else "Tidak diketahui"

    def get_info_popup(self) -> str:
        return (f"<h4><b>{self.nama}</b></h4>"
                f"<i>Kuliner</i><br><br>"
                f"Menu Andalan: {self.menu_andalan}<br><br>"
                f"Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})")


class TempatIbadah(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, agama: str = "Umum", deskripsi: str = ""):
        super().__init__(nama, latitude, longitude)
        self.agama = str(agama) if agama else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tempat Ibadah"

    def get_info_popup(self) -> str:
        return (f"<h4><b>{self.nama}</b></h4>"
                f"<i>Tempat Ibadah ({self.agama})</i><br><br>"
                f"{self.deskripsi}<br><br>"
                f"Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})")


print("--- Praktikum 3: Kelas OOP Berhasil Didefinisikan ---")
print("Kelas yang didefinisikan: Lokasi (ABC), TempatWisata, Kuliner, TempatIbadah")

# Demonstrasi instansiasi
demo_wisata = TempatWisata("Lawang Sewu", -6.9840, 110.4105, "Wisata Sejarah", "Bangunan bersejarah")
demo_kuliner = Kuliner("Toko Oen", -6.9715, 110.4235, "Es Krim & Makanan Belanda")
print(f"\nContoh objek:")
print(repr(demo_wisata))
print(repr(demo_kuliner))
print("\n--- Praktikum 3 Selesai ---")
# Out:
# --- Praktikum 3: Kelas OOP Berhasil Didefinisikan ---
# Kelas yang didefinisikan: Lokasi (ABC), TempatWisata, Kuliner, TempatIbadah
#
# Contoh objek:
# TempatWisata(nama='Lawang Sewu', lat=-6.9840, lon=110.4105)
# Kuliner(nama='Toko Oen', lat=-6.9715, lon=110.4235)
#
# --- Praktikum 3 Selesai ---

# %% [markdown]
# ---
# ### Langkah 4: Praktikum 4 — Membuat Objek dari Data Pandas

# %%
# Praktikum 4: Membuat Objek dari Data Pandas

def buat_objek_lokasi_dari_df(dataframe) -> list:
    """
    Mengiterasi DataFrame Pandas dan membuat list berisi objek-objek
    Lokasi (atau turunannya) berdasarkan data di setiap baris.

    Args:
        dataframe (pd.DataFrame): DataFrame yang berisi data lokasi
                                  dengan kolom 'Nama', 'Latitude', 'Longitude',
                                  'Tipe', 'Deskripsi'.

    Returns:
        list: List berisi instance objek Lokasi atau turunannya.
    """
    list_objek_lokasi = []
    if dataframe is None or dataframe.empty:
        print("DataFrame kosong atau None, tidak ada objek dibuat.")
        return list_objek_lokasi

    print("\nMembuat objek dari DataFrame...")
    for index, row in dataframe.iterrows():
        nama      = row.get('Nama', None)
        lat       = row.get('Latitude', None)
        lon       = row.get('Longitude', None)
        tipe      = row.get('Tipe', 'Lainnya')
        deskripsi = row.get('Deskripsi', '')

        objek = None
        if nama is None or lat is None or lon is None:
            print(f" -> Melewati baris {index}: Data Nama/Latitude/Longitude tidak lengkap.")
            continue

        try:
            if 'Wisata' in tipe or tipe == 'Landmark':
                objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
            elif tipe == 'Kuliner':
                objek = Kuliner(nama, lat, lon, deskripsi)
            elif 'Ibadah' in tipe:
                agama_info = "Umum"
                if "Islam" in tipe: agama_info = "Islam"
                elif "Kristen" in tipe: agama_info = "Kristen"
                elif "Klenteng" in tipe: agama_info = "Tridharma"
                objek = TempatIbadah(nama, lat, lon, agama_info, deskripsi)
            else:
                print(f" -> Peringatan: Tipe '{tipe}' untuk '{nama}' tidak dikenali. Tidak membuat objek spesifik.")

            if objek:
                list_objek_lokasi.append(objek)

        except Exception as e:
            print(f" -> GAGAL membuat objek untuk '{nama}' di baris {index}: {e}")

    print(f"Total {len(list_objek_lokasi)} objek lokasi berhasil dibuat dari {len(dataframe)} baris data.")
    return list_objek_lokasi


# --- Kode Utama ---
NAMA_FILE_CSV = "lokasi_semarang.csv"

print("--- Memulai Praktikum 4: Membuat Objek dari Data Pandas ---")
df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)
list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)

print("\n--- Daftar Objek Lokasi yang Berhasil Dibuat ---")
if list_semua_lokasi:
    for idx, lok in enumerate(list_semua_lokasi):
        print(f"{idx+1}. {repr(lok)}")
else:
    print("Tidak ada objek lokasi yang dibuat.")

print("\n--- Praktikum 4 Selesai ---")
# Out:
# --- Memulai Praktikum 4: Membuat Objek dari Data Pandas ---
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# Membuat objek dari DataFrame...
# Total 10 objek lokasi berhasil dibuat dari 10 baris data.
#
# --- Daftar Objek Lokasi yang Berhasil Dibuat ---
# 1. TempatWisata(nama='Lawang Sewu', lat=-6.9840, lon=110.4105)
# 2. TempatWisata(nama='Simpang Lima', lat=-6.9929, lon=110.4200)
# 3. TempatIbadah(nama='Masjid Agung Jawa Tengah', lat=-6.9892, lon=110.4452)
# 4. TempatIbadah(nama='Klenteng Sam Poo Kong', lat=-6.9980, lon=110.4030)
# 5. TempatWisata(nama='Brown Canyon', lat=-7.0375, lon=110.4875)
# 6. Kuliner(nama='Lumpia Gang Lombok', lat=-6.9718, lon=110.4255)
# 7. TempatWisata(nama='Kota Lama', lat=-6.9690, lon=110.4250)
# 8. TempatWisata(nama='Pantai Marina', lat=-6.9585, lon=110.3875)
# 9. TempatWisata(nama='Kampoeng Kopi Banaran', lat=-7.2780, lon=110.4010)
# 10. Kuliner(nama='Toko Oen', lat=-6.9715, lon=110.4235)
#
# --- Praktikum 4 Selesai ---

# %% [markdown]
# ---
# ### Langkah 5: Praktikum 5 — Visualisasi Peta dengan Folium

# %%
# Praktikum 5: Visualisasi Peta dengan Folium
import folium

def buat_peta_lokasi_folium(list_objek: list, file_output: str = "peta_lokasi.html"):
    """
    Membuat peta Folium interaktif dengan marker untuk setiap objek
    dalam list_objek.

    Args:
        list_objek (list): List berisi instance objek turunan Lokasi.
        file_output (str): Nama file HTML untuk menyimpan peta.
    """
    if not list_objek:
        print("Tidak ada objek lokasi untuk dipetakan.")
        return

    print(f"\nMemulai pembuatan peta Folium dari {len(list_objek)} lokasi...")

    try:
        lat_tengah = list_objek[0].latitude
        lon_tengah = list_objek[0].longitude
    except IndexError:
        lat_tengah, lon_tengah = -6.9929, 110.4200

    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=13, tiles="OpenStreetMap")
    print(f" -> Objek peta dibuat, berpusat di ({lat_tengah:.4f}, {lon_tengah:.4f})")

    jumlah_marker_valid = 0
    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama
            ).add_to(peta)
            jumlah_marker_valid += 1
        else:
            print(f" -> Melewati marker untuk '{lok.nama}' karena koordinat tidak valid.")

    try:
        peta.save(file_output)
        print(f"\n-> Peta berhasil dibuat dan disimpan sebagai '{file_output}'.")
        print(f"   Total marker ditambahkan: {jumlah_marker_valid}")
    except Exception as e:
        print(f"\nERROR saat menyimpan peta Folium: {type(e).__name__} - {e}")

    return peta


# --- Kode Utama ---
NAMA_FILE_CSV  = "lokasi_semarang.csv"
NAMA_FILE_PETA = "peta_interaktif_semarang.html"

print("--- Memulai Praktikum 5: Visualisasi Peta dengan Folium ---")
df_lokasi         = baca_data_lokasi(NAMA_FILE_CSV)
list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)
peta_hasil        = buat_peta_lokasi_folium(list_semua_lokasi, NAMA_FILE_PETA)

# Tampilkan peta langsung di Colab
peta_hasil
# Out:
# --- Memulai Praktikum 5: Visualisasi Peta dengan Folium ---
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# Membuat objek dari DataFrame...
# Total 10 objek lokasi berhasil dibuat dari 10 baris data.
#
# Memulai pembuatan peta Folium dari 10 lokasi...
#  -> Objek peta dibuat, berpusat di (-6.9840, 110.4105)
#
# -> Peta berhasil dibuat dan disimpan sebagai 'peta_interaktif_semarang.html'.
#    Total marker ditambahkan: 10
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_219a6c132b5b3be4f0a332ebf05be037 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_219a6c132b5b3be4f0a332ebf05be037&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_219a6c132b5b3be4f0a332ebf05be037 = L.map(
#                 &quot;map_219a6c132b5b3be4f0a332ebf05be037&quot;,
#                 {
#                     center: [-6.984, 110.4105],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91c810b9a63fb433de46f75c5f69e7c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91c810b9a63fb433de46f75c5f69e7c0.addTo(map_219a6c132b5b3be4f0a332ebf05be037);
#
#
#             var marker_6fb659cf4efdc0770625e39a6619d341 = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_219a6c132b5b3be4f0a332ebf05be037);
#
#
#         var popup_de16b64b5fa5b297a9e87905b3bbd311 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_599c576143f197ff0342b1792c5bcb86 = $(`&lt;div id=&quot;html_599c576143f197ff0342b1792c5bcb86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Lawang Sewu&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Wisata Sejarah&lt;/i&gt;&lt;br&gt;&lt;br&gt;Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_de16b64b5fa5b297a9e87905b3bbd311.setContent(html_599c576143f197ff0342b1792c5bcb86);
#
#
#
#         marker_6fb659cf4efdc0770625e39a6619d341.bindPopup(popup_de16b64b5fa5b297a9e87905b3bbd311)
#         ;
#
#
#
#
#             marker_6fb659cf4efdc0770625e39a6619d341.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1a5bc9c151c300f84b8a359a4d7df231 = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_219a6c132b5b3be4f0a332ebf05be037);
#
#
#         var popup_4d8483974678b6a366def6e16ad956ae = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7ab2e859e4b97b3537ebfb71807f3b86 = $(`&lt;div id=&quot;html_7ab2e859e4b97b3537ebfb71807f3b86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Simpang Lima&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Landmark&lt;/i&gt;&lt;br&gt;&lt;br&gt;Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_4d8483974678b6a366def6e16ad956ae.setContent(html_7ab2e859e4b97b3537ebfb71807f3b86);
#
#
#
#         marker_1a5bc9c151c300f84b8a359a4d7df231.bindPopup(popup_4d8483974678b6a366def6e16ad956ae)
#         ;
#
#
#
#
#             marker_1a5bc9c151c300f84b8a359a4d7df231.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_46451f79c43b326c275192cd8ba7b5f9 = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_219a6c132b5b3be4f0a332ebf05be037);
#
#
#         var popup_bd0e2d4dce4282bc5cf4a0d713f1d482 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f7052b14a708fa2ec382d7db6ae5521f = $(`&lt;div id=&quot;html_f7052b14a708fa2ec382d7db6ae5521f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Masjid Agung Jawa Tengah&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Tempat Ibadah (Umum)&lt;/i&gt;&lt;br&gt;&lt;br&gt;Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9892, 110.4452)&lt;/div&gt;`)[0];
#                 popup_bd0e2d4dce4282bc5cf4a0d713f1d482.setContent(html_f7052b14a708fa2ec382d7db6ae5521f);
#
#
#
#         marker_46451f79c43b326c275192cd8ba7b5f9.bindPopup(popup_bd0e2d4dce4282bc5cf4a0d713f1d482)
#         ;
#
#
#
#
#             marker_46451f79c43b326c275192cd8ba7b5f9.bindTooltip(
#                 `&lt;div&gt;
#                      Masjid Agung Jawa Tengah
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_60e22dbd1cff53fc1977cda8fa4f8271 = L.marker(
#                 [-6.998, 110.403],
#                 {
# }
#             ).addTo(map_219a6c132b5b3be4f0a332ebf05be037);

# %% [markdown]
# ---
# ### Langkah 6: Praktikum 6 — File Handling Tambahan (Menyimpan Log)

# %%
# Praktikum 6: File Handling Tambahan (Menyimpan Log)
import datetime

def tulis_log(pesan: str, file_log: str = "proses_peta.log"):
    """Menulis pesan log ke file dengan timestamp, menggunakan mode append."""
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    try:
        with open(file_log, 'a', encoding='utf-8') as f:
            f.write(f"[{timestamp}] {pesan}\n")
    except IOError as e:
        print(f"ERROR: Gagal menulis ke file log '{file_log}': {e}")


def buat_peta_lokasi_folium_log(list_objek: list, file_output: str = "peta_lokasi.html"):
    """
    Membuat peta Folium, menambahkan marker, menyimpan ke HTML,
    dan menulis log proses.
    """
    nama_fungsi = "buat_peta_lokasi_folium"

    if not list_objek:
        pesan_log = f"[{nama_fungsi}] Gagal: Tidak ada data lokasi untuk dipetakan."
        print(pesan_log)
        tulis_log(pesan_log)
        return

    print(f"\n[{nama_fungsi}] Memulai pembuatan peta dari {len(list_objek)} lokasi...")
    tulis_log(f"[{nama_fungsi}] Memulai pembuatan peta '{file_output}' dengan {len(list_objek)} lokasi.")

    try:
        lat_tengah = list_objek[0].latitude
        lon_tengah = list_objek[0].longitude
    except IndexError:
        lat_tengah, lon_tengah = -6.9929, 110.4200

    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=12)

    jumlah_marker = 0
    lokasi_dilewati = []
    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama
            ).add_to(peta)
            jumlah_marker += 1
        else:
            lokasi_dilewati.append(lok.nama)

    if lokasi_dilewati:
        pesan_lewat = f"[{nama_fungsi}] Melewati marker untuk: {', '.join(lokasi_dilewati)} (koordinat tidak valid)."
        print(f" -> Peringatan: {pesan_lewat}")
        tulis_log(pesan_lewat)

    try:
        peta.save(file_output)
        pesan_sukses = f"[{nama_fungsi}] Peta '{file_output}' berhasil dibuat dengan {jumlah_marker} marker."
        print(f"-> {pesan_sukses}")
        tulis_log(pesan_sukses)
    except Exception as e:
        pesan_error = f"[{nama_fungsi}] ERROR saat menyimpan peta '{file_output}': {type(e).__name__} - {e}"
        print(f"-> {pesan_error}")
        tulis_log(pesan_error)

    return peta


# --- Kode Utama ---
NAMA_FILE_CSV  = "lokasi_semarang.csv"
NAMA_FILE_PETA = "peta_interaktif_semarang.html"
FILE_LOG       = "proses_peta.log"

print("--- Memulai Praktikum 6: File Handling Tambahan (Log) ---")
df_lokasi         = baca_data_lokasi(NAMA_FILE_CSV)
list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)
buat_peta_lokasi_folium_log(list_semua_lokasi, NAMA_FILE_PETA)

# Jalankan lagi untuk demo log append
print("\nMenjalankan pembuatan peta lagi untuk demo log append...")
buat_peta_lokasi_folium_log(list_semua_lokasi, "peta_kedua.html")

# Tampilkan isi log
print(f"\nIsi file log '{FILE_LOG}':")
with open(FILE_LOG, 'r', encoding='utf-8') as f:
    print(f.read())

print("--- Praktikum 6 Selesai ---")
# Out:
# --- Memulai Praktikum 6: File Handling Tambahan (Log) ---
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# Membuat objek dari DataFrame...
# Total 10 objek lokasi berhasil dibuat dari 10 baris data.
#
# [buat_peta_lokasi_folium] Memulai pembuatan peta dari 10 lokasi...
# -> [buat_peta_lokasi_folium] Peta 'peta_interaktif_semarang.html' berhasil dibuat dengan 10 marker.
#
# Menjalankan pembuatan peta lagi untuk demo log append...
#
# [buat_peta_lokasi_folium] Memulai pembuatan peta dari 10 lokasi...
# -> [buat_peta_lokasi_folium] Peta 'peta_kedua.html' berhasil dibuat dengan 10 marker.
#
# Isi file log 'proses_peta.log':
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Memulai pembuatan peta 'peta_interaktif_semarang.html' dengan 10 lokasi.
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Peta 'peta_interaktif_semarang.html' berhasil dibuat dengan 10 marker.
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Memulai pembuatan peta 'peta_kedua.html' dengan 10 lokasi.
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Peta 'peta_kedua.html' berhasil dibuat dengan 10 marker.
#
# --- Praktikum 6 Selesai ---

# %% [markdown]
# ---
# ## Penugasan 3 — Mini Project SIG
# ### Langkah (a) Tambah Data & Kelas Baru

# %%
# Penugasan 3a: Tambah data CSV (3 lokasi baru) + 2 kelas anak baru

# ---- Update CSV dengan 3 lokasi baru ----
csv_content_baru = """Nama,Latitude,Longitude,Tipe,Deskripsi
Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
Simpang Lima,-6.9929,110.4200,Landmark,"Alun-alun pusat kota Semarang, tempat berkumpul populer."
Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.
Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
Brown Canyon,-7.0375,110.4875,Wisata Alam,"Tebing bekas penambangan galian C yang unik menyerupai Grand Canyon."
Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris dan otentik di Semarang.
Kota Lama,-6.9690,110.4250,Wisata Sejarah,"Kawasan cagar budaya dengan bangunan-bangunan kuno bergaya Eropa."
Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi di bagian utara kota.
Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,"Agrowisata kebun kopi dengan pemandangan dan restoran."
Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris sejak zaman kolonial.
Balai Kota Semarang,-6.9872,110.4182,Kantor Pemerintahan,Pusat pemerintahan Kota Semarang yang berdiri sejak zaman Belanda.
Museum Mandala Bhakti,-6.9843,110.4160,Museum,Museum militer yang menyimpan koleksi senjata dan memorabilia perjuangan.
Taman Diponegoro,-6.9917,110.4103,Taman Kota,"Taman kota dengan patung Pangeran Diponegoro, cocok untuk bersantai."
"""

with open('lokasi_semarang.csv', 'w', encoding='utf-8') as f:
    f.write(csv_content_baru)

print("File lokasi_semarang.csv diperbarui dengan 3 lokasi baru.")

# ---- Definisi 2 Kelas Anak Baru ----
class Museum(Lokasi):
    """Merepresentasikan lokasi museum."""
    def __init__(self, nama: str, latitude: float, longitude: float, deskripsi: str = ""):
        super().__init__(nama, latitude, longitude)
        self.deskripsi = str(deskripsi) if deskripsi else "Museum"

    def get_info_popup(self) -> str:
        return (f"<h4><b>{self.nama}</b></h4>"
                f"<i>\U0001F3DB Museum</i><br><br>"
                f"{self.deskripsi}<br><br>"
                f"Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})")


class TamanKota(Lokasi):
    """Merepresentasikan lokasi taman kota."""
    def __init__(self, nama: str, latitude: float, longitude: float, deskripsi: str = ""):
        super().__init__(nama, latitude, longitude)
        self.deskripsi = str(deskripsi) if deskripsi else "Taman Kota"

    def get_info_popup(self) -> str:
        return (f"<h4><b>{self.nama}</b></h4>"
                f"<i>\U0001F333 Taman Kota</i><br><br>"
                f"{self.deskripsi}<br><br>"
                f"Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})")


class KantorPemerintahan(Lokasi):
    """Merepresentasikan kantor pemerintahan."""
    def __init__(self, nama: str, latitude: float, longitude: float, deskripsi: str = ""):
        super().__init__(nama, latitude, longitude)
        self.deskripsi = str(deskripsi) if deskripsi else "Kantor Pemerintahan"

    def get_info_popup(self) -> str:
        return (f"<h4><b>{self.nama}</b></h4>"
                f"<i>\U0001F3DB Kantor Pemerintahan</i><br><br>"
                f"{self.deskripsi}<br><br>"
                f"Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})")

print("\nKelas baru berhasil didefinisikan: Museum, TamanKota, KantorPemerintahan")

# ---- Modifikasi fungsi buat_objek agar mengenali tipe baru ----
def buat_objek_lokasi_dari_df_v2(dataframe) -> list:
    """
    Versi 2: mengenali tipe Museum, Taman Kota, dan Kantor Pemerintahan.
    """
    list_objek_lokasi = []
    if dataframe is None or dataframe.empty:
        print("DataFrame kosong atau None, tidak ada objek dibuat.")
        return list_objek_lokasi

    print("\nMembuat objek dari DataFrame (v2)...")
    for index, row in dataframe.iterrows():
        nama      = row.get('Nama', None)
        lat       = row.get('Latitude', None)
        lon       = row.get('Longitude', None)
        tipe      = row.get('Tipe', 'Lainnya')
        deskripsi = row.get('Deskripsi', '')

        objek = None
        if nama is None or lat is None or lon is None:
            print(f" -> Melewati baris {index}: Data Nama/Latitude/Longitude tidak lengkap.")
            continue

        try:
            if 'Wisata' in tipe or tipe == 'Landmark':
                objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
            elif tipe == 'Kuliner':
                objek = Kuliner(nama, lat, lon, deskripsi)
            elif 'Ibadah' in tipe:
                agama_info = "Umum"
                if "Islam" in tipe: agama_info = "Islam"
                elif "Kristen" in tipe: agama_info = "Kristen"
                elif "Klenteng" in tipe: agama_info = "Tridharma"
                objek = TempatIbadah(nama, lat, lon, agama_info, deskripsi)
            elif tipe == 'Museum':
                objek = Museum(nama, lat, lon, deskripsi)
            elif tipe == 'Taman Kota':
                objek = TamanKota(nama, lat, lon, deskripsi)
            elif tipe == 'Kantor Pemerintahan':
                objek = KantorPemerintahan(nama, lat, lon, deskripsi)
            else:
                print(f" -> Peringatan: Tipe '{tipe}' untuk '{nama}' tidak dikenali.")

            if objek:
                list_objek_lokasi.append(objek)

        except Exception as e:
            print(f" -> GAGAL membuat objek untuk '{nama}' di baris {index}: {e}")

    print(f"Total {len(list_objek_lokasi)} objek lokasi berhasil dibuat dari {len(dataframe)} baris data.")
    return list_objek_lokasi


# Test fungsi baru
df_v2  = baca_data_lokasi('lokasi_semarang.csv')
list_v2 = buat_objek_lokasi_dari_df_v2(df_v2)

print("\n--- Daftar Semua Objek (termasuk tipe baru) ---")
for idx, lok in enumerate(list_v2):
    print(f"{idx+1}. {repr(lok)}")
# Out:
# File lokasi_semarang.csv diperbarui dengan 3 lokasi baru.
#
# Kelas baru berhasil didefinisikan: Museum, TamanKota, KantorPemerintahan
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# Membuat objek dari DataFrame (v2)...
# Total 13 objek lokasi berhasil dibuat dari 13 baris data.
#
# --- Daftar Semua Objek (termasuk tipe baru) ---
# 1. TempatWisata(nama='Lawang Sewu', lat=-6.9840, lon=110.4105)
# 2. TempatWisata(nama='Simpang Lima', lat=-6.9929, lon=110.4200)
# 3. TempatIbadah(nama='Masjid Agung Jawa Tengah', lat=-6.9892, lon=110.4452)
# 4. TempatIbadah(nama='Klenteng Sam Poo Kong', lat=-6.9980, lon=110.4030)
# 5. TempatWisata(nama='Brown Canyon', lat=-7.0375, lon=110.4875)
# 6. Kuliner(nama='Lumpia Gang Lombok', lat=-6.9718, lon=110.4255)
# 7. TempatWisata(nama='Kota Lama', lat=-6.9690, lon=110.4250)
# 8. TempatWisata(nama='Pantai Marina', lat=-6.9585, lon=110.3875)
# 9. TempatWisata(nama='Kampoeng Kopi Banaran', lat=-7.2780, lon=110.4010)
# 10. Kuliner(nama='Toko Oen', lat=-6.9715, lon=110.4235)
# 11. KantorPemerintahan(nama='Balai Kota Semarang', lat=-6.9872, lon=110.4182)
# 12. Museum(nama='Museum Mandala Bhakti', lat=-6.9843, lon=110.4160)
# 13. TamanKota(nama='Taman Diponegoro', lat=-6.9917, lon=110.4103)

# %% [markdown]
# ---
# ### Langkah (b) Kustomisasi Marker Folium + (c) Baca Konfigurasi dari File

# %%
# Penugasan 3b & 3c: Marker berwarna berbeda + baca konfigurasi dari file

# ---- 3c: Buat file config_peta.txt ----
with open('config_peta.txt', 'w', encoding='utf-8') as f:
    f.write("-6.9929\n")
    f.write("110.4200\n")
    f.write("13\n")

print("File config_peta.txt berhasil dibuat.")
print("Isi config_peta.txt:")
with open('config_peta.txt', 'r', encoding='utf-8') as f:
    print(f.read())


def baca_config_peta(file_config: str = "config_peta.txt"):
    """
    Membaca konfigurasi peta dari file teks.
    Format file: baris 1=latitude, baris 2=longitude, baris 3=zoom_start.
    """
    lat_default, lon_default, zoom_default = -6.9929, 110.4200, 13
    try:
        with open(file_config, 'r', encoding='utf-8') as f:
            baris = f.readlines()
        lat   = float(baris[0].strip())
        lon   = float(baris[1].strip())
        zoom  = int(baris[2].strip())
        print(f" -> Konfigurasi peta dibaca: lat={lat}, lon={lon}, zoom={zoom}")
        return lat, lon, zoom
    except FileNotFoundError:
        print(f" -> PERINGATAN: File '{file_config}' tidak ditemukan. Menggunakan nilai default.")
    except (ValueError, IndexError) as e:
        print(f" -> PERINGATAN: Format file konfigurasi tidak valid ({e}). Menggunakan nilai default.")
    return lat_default, lon_default, zoom_default


def tentukan_icon(lok) -> folium.Icon:
    """
    Menentukan ikon marker Folium berdasarkan tipe objek lokasi.
    """
    if isinstance(lok, TempatWisata):
        return folium.Icon(color='blue', icon='camera', prefix='fa')
    elif isinstance(lok, Kuliner):
        return folium.Icon(color='red', icon='cutlery', prefix='fa')
    elif isinstance(lok, TempatIbadah):
        return folium.Icon(color='purple', icon='star', prefix='fa')
    elif isinstance(lok, Museum):
        return folium.Icon(color='orange', icon='university', prefix='fa')
    elif isinstance(lok, TamanKota):
        return folium.Icon(color='green', icon='tree', prefix='fa')
    elif isinstance(lok, KantorPemerintahan):
        return folium.Icon(color='gray', icon='building', prefix='fa')
    else:
        return folium.Icon(color='black', icon='info-sign')


def buat_peta_mini_project(
    list_objek: list,
    file_output: str = "peta_mini_project.html",
    file_config: str = "config_peta.txt"
):
    """
    Fungsi utama mini project:
    - Baca konfigurasi dari file (3c)
    - Marker berbeda warna/ikon per tipe (3b)
    - Tulis log proses (Praktikum 6)
    """
    if not list_objek:
        msg = "Gagal: Tidak ada data lokasi untuk dipetakan."
        print(msg); tulis_log(msg)
        return

    # 3c: Baca konfigurasi peta dari file
    lat_tengah, lon_tengah, zoom = baca_config_peta(file_config)

    tulis_log(f"Memulai pembuatan peta '{file_output}' dengan {len(list_objek)} lokasi.")

    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=zoom, tiles="OpenStreetMap")

    # Tambahkan legenda warna
    legenda_html = """
    <div style="position:fixed; bottom:30px; left:30px; z-index:1000;
                background:white; padding:12px 16px; border-radius:8px;
                border:2px solid #ccc; font-size:13px; line-height:1.8;">
        <b>\U0001F5FA Legenda</b><br>
        <span style="color:blue;">&#9679;</span> Wisata / Landmark<br>
        <span style="color:red;">&#9679;</span> Kuliner<br>
        <span style="color:purple;">&#9679;</span> Tempat Ibadah<br>
        <span style="color:orange;">&#9679;</span> Museum<br>
        <span style="color:green;">&#9679;</span> Taman Kota<br>
        <span style="color:gray;">&#9679;</span> Kantor Pemerintahan
    </div>
    """
    peta.get_root().html.add_child(folium.Element(legenda_html))

    jumlah_marker = 0
    lokasi_dilewati = []
    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            # 3b: Gunakan ikon berbeda sesuai tipe
            ikon = tentukan_icon(lok)
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama,
                icon=ikon
            ).add_to(peta)
            jumlah_marker += 1
        else:
            lokasi_dilewati.append(lok.nama)

    if lokasi_dilewati:
        msg = f"Melewati marker untuk: {', '.join(lokasi_dilewati)} (koordinat tidak valid)."
        print(f" -> Peringatan: {msg}")
        tulis_log(msg)

    try:
        peta.save(file_output)
        msg_sukses = f"Peta '{file_output}' berhasil dibuat dengan {jumlah_marker} marker."
        print(f"-> {msg_sukses}")
        tulis_log(msg_sukses)
    except Exception as e:
        msg_err = f"ERROR saat menyimpan peta '{file_output}': {type(e).__name__} - {e}"
        print(f"-> {msg_err}")
        tulis_log(msg_err)

    return peta


print("Fungsi baca_config_peta dan buat_peta_mini_project berhasil didefinisikan.")
# Out:
# File config_peta.txt berhasil dibuat.
# Isi config_peta.txt:
# -6.9929
# 110.4200
# 13
#
# Fungsi baca_config_peta dan buat_peta_mini_project berhasil didefinisikan.

# %% [markdown]
# ---
# ### Langkah (d) Kode Utama Mini Project SIG

# %%
# Penugasan 3d: Kode Utama Mini Project SIG
NAMA_FILE_CSV    = "lokasi_semarang.csv"
NAMA_FILE_CONFIG = "config_peta.txt"
NAMA_FILE_PETA   = "peta_mini_project_semarang.html"

print("======================================================")
print(" MINI PROJECT SIG — Peta Interaktif Kota Semarang")
print("======================================================")

# 1. Baca data CSV
df_mini = baca_data_lokasi(NAMA_FILE_CSV)

# 2. Buat list objek (termasuk tipe baru)
list_mini = buat_objek_lokasi_dari_df_v2(df_mini)

# Ringkasan tipe objek
print("\n--- Ringkasan Tipe Objek ---")
from collections import Counter
tipe_counter = Counter(type(lok).__name__ for lok in list_mini)
for tipe, jumlah in tipe_counter.items():
    print(f"  {tipe}: {jumlah} lokasi")

# 3. Buat peta mini project (marker berwarna + config dari file)
peta_mini = buat_peta_mini_project(list_mini, NAMA_FILE_PETA, NAMA_FILE_CONFIG)

print("\n--- Log Proses ---")
with open('proses_peta.log', 'r', encoding='utf-8') as f:
    print(f.read())

print("\n--- Mini Project SIG Selesai ---")

# Tampilkan peta langsung di Colab
peta_mini
# Out:
# ======================================================
#  MINI PROJECT SIG — Peta Interaktif Kota Semarang
# ======================================================
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# Membuat objek dari DataFrame (v2)...
# Total 13 objek lokasi berhasil dibuat dari 13 baris data.
#
# --- Ringkasan Tipe Objek ---
#   TempatWisata: 6 lokasi
#   TempatIbadah: 2 lokasi
#   Kuliner: 2 lokasi
#   KantorPemerintahan: 1 lokasi
#   Museum: 1 lokasi
#   TamanKota: 1 lokasi
#  -> Konfigurasi peta dibaca: lat=-6.9929, lon=110.42, zoom=13
# -> Peta 'peta_mini_project_semarang.html' berhasil dibuat dengan 13 marker.
#
# --- Log Proses ---
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Memulai pembuatan peta 'peta_interaktif_semarang.html' dengan 10 lokasi.
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Peta 'peta_interaktif_semarang.html' berhasil dibuat dengan 10 marker.
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Memulai pembuatan peta 'peta_kedua.html' dengan 10 lokasi.
# [2026-06-25 23:26:33] [buat_peta_lokasi_folium] Peta 'peta_kedua.html' berhasil dibuat dengan 10 marker.
# [2026-06-25 23:39:54] Memulai pembuatan peta 'peta_mini_project_semarang.html' dengan 13 lokasi.
# [2026-06-25 23:39:54] Peta 'peta_mini_project_semarang.html' berhasil dibuat dengan 13 marker.
#
#
# --- Mini Project SIG Selesai ---
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b535783b4bc9255a23d4c90bd4a9207d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed; bottom:30px; left:30px; z-index:1000;
#                 background:white; padding:12px 16px; border-radius:8px;
#                 border:2px solid #ccc; font-size:13px; line-height:1.8;&quot;&gt;
#         &lt;b&gt;🗺 Legenda&lt;/b&gt;&lt;br&gt;
#         &lt;span style=&quot;color:blue;&quot;&gt;&amp;#9679;&lt;/span&gt; Wisata / Landmark&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;&amp;#9679;&lt;/span&gt; Kuliner&lt;br&gt;
#         &lt;span style=&quot;color:purple;&quot;&gt;&amp;#9679;&lt;/span&gt; Tempat Ibadah&lt;br&gt;
#         &lt;span style=&quot;color:orange;&quot;&gt;&amp;#9679;&lt;/span&gt; Museum&lt;br&gt;
#         &lt;span style=&quot;color:green;&quot;&gt;&amp;#9679;&lt;/span&gt; Taman Kota&lt;br&gt;
#         &lt;span style=&quot;color:gray;&quot;&gt;&amp;#9679;&lt;/span&gt; Kantor Pemerintahan
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b535783b4bc9255a23d4c90bd4a9207d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b535783b4bc9255a23d4c90bd4a9207d = L.map(
#                 &quot;map_b535783b4bc9255a23d4c90bd4a9207d&quot;,
#                 {
#                     center: [-6.9929, 110.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d765e3aa7f6f67667cc0f6863e4aa476 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d765e3aa7f6f67667cc0f6863e4aa476.addTo(map_b535783b4bc9255a23d4c90bd4a9207d);
#
#
#             var marker_9b16391ca47eef3155593eff2202719d = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_b535783b4bc9255a23d4c90bd4a9207d);
#
#
#             var icon_b460b0cb5351f141bef612df90367007 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2f567cfb2143739d427529c7b355df35 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4abfecfda3f1c42835341bfe366e0a7a = $(`&lt;div id=&quot;html_4abfecfda3f1c42835341bfe366e0a7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Lawang Sewu&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Wisata Sejarah&lt;/i&gt;&lt;br&gt;&lt;br&gt;Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_2f567cfb2143739d427529c7b355df35.setContent(html_4abfecfda3f1c42835341bfe366e0a7a);
#
#
#
#         marker_9b16391ca47eef3155593eff2202719d.bindPopup(popup_2f567cfb2143739d427529c7b355df35)
#         ;
#
#
#
#
#             marker_9b16391ca47eef3155593eff2202719d.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9b16391ca47eef3155593eff2202719d.setIcon(icon_b460b0cb5351f141bef612df90367007);
#
#
#             var marker_264df7dc72fdfc7855baf85290fa442e = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_b535783b4bc9255a23d4c90bd4a9207d);
#
#
#             var icon_a454e2c4035e24a80e677374675568c2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_eb500170212cd36999a4851957efaf3f = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_35e22ba4eff9178a9d1cbc4c28e7e95f = $(`&lt;div id=&quot;html_35e22ba4eff9178a9d1cbc4c28e7e95f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Simpang Lima&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Landmark&lt;/i&gt;&lt;br&gt;&lt;br&gt;Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_eb500170212cd36999a4851957efaf3f.setContent(html_35e22ba4eff9178a9d1cbc4c28e7e95f);
#
#
#
#         marker_264df7dc72fdfc7855baf85290fa442e.bindPopup(popup_eb500170212cd36999a4851957efaf3f)
#         ;
